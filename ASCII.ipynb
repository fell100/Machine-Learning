# %% [markdown]
# <a href="https://colab.research.google.com/github/fell100/Machine-Learning/blob/master/ASCII.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab import drive
import math
import time

# %%
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
keth = cv2.imread("/content/drive/MyDrive/HistogramasPDI/imagens/keth_gray.jpg", cv2.IMREAD_GRAYSCALE)

# %%
imsize = 128

# %%
keth.shape
# Out:
# (3385, 1844)

# %%
'abc'[::-1]
# Out:
# 'cba'

# %%
def get_character(intensity):
  ascii_string = "$@B%8&WM#*oahkbdpqwmZO0QLCJUYXzcvunxrjft/\|()1{}[]?-_+~<>i!lI;:,^`'. "[::-1]
  ascii_string = list(ascii_string)[::-1]
  return ascii_string[int(int( np.round(int(intensity) * int(len(ascii_string))/255) ) -1)]

# %%
get_character(255)
# Out:
# ' '

# %%
plt.imshow(keth, cmap='gray')

# %%
keth = cv2.GaussianBlur(keth,(35,35),0)
keth = cv2.resize(keth, (100,100))[:78]
plt.imshow(keth, cmap='gray')

# %%
keth.shape
# Out:
# (78, 100)

# %%
keth = keth.astype('U')

# %%
def ascii_img(img):
  W, H = img.shape 
  for v in range(0,H): 
      for u in range(0,W):
          img[u,v] = get_character(img[u,v])
  return img

# %%
keth[0][:]
# Out:
# array(['242', '242', '242', '242', '242', '242', '242', '242', '242',
#        '242', '242', '242', '242', '242', '242', '242', '242', '242',
#        '242', '242', '242', '242', '242', '242', '242', '242', '243',
#        '242', '242', '241', '240', '240', '238', '237', '237', '237',
#        '237', '238', '240', '240', '241', '242', '243', '243', '243',
#        '243', '243', '243', '243', '243', '243', '243', '243', '243',
#        '243', '243', '243', '243', '243', '243', '243', '243', '243',
#        '243', '243', '243', '243', '243', '244', '243', '244', '244',
#        '244', '244', '244', '244', '244', '244', '244', '244', '243',
#        '244', '244', '244', '244', '244', '244', '244', '244', '244',
#        '244', '244', '244', '244', '244', '244', '244', '244', '244',
#        '244'], dtype='<U3')

# %%
ascii_keth = ascii_img(keth)

# %%
with open("test.txt",'w',encoding = 'utf-8') as f:
  h, w = keth.shape
  x = ""
  for j in range(0,h):
    for i in ascii_keth[j][:]:
      x+= i
    f.write(f"{x}\n")
    x = ""

# %%
import os
os.system("cat ~/file.txt")
# Out:
# 256

# %%
mae1 = cv2.imread("/content/drive/MyDrive/HistogramasPDI/imagens/mae.jpg", cv2.IMREAD_GRAYSCALE)
mae2 = cv2.imread("/content/drive/MyDrive/HistogramasPDI/imagens/mae2.jpg", cv2.IMREAD_GRAYSCALE)
irma = cv2.imread("/content/drive/MyDrive/HistogramasPDI/imagens/irma.jpg", cv2.IMREAD_GRAYSCALE)

# %%
mae1 = cv2.GaussianBlur(mae1,(35,35),0)
mae1 = cv2.resize(mae1, (200,200))[:100]
plt.imshow(mae1, cmap='gray')

# %%
mae2 = cv2.GaussianBlur(mae2,(15,15),0)
mae2 = cv2.resize(mae2, (350,350))[:200]
plt.imshow(mae2, cmap='gray')

# %%
irma = cv2.GaussianBlur(irma,(25,25),0)
irma = cv2.resize(irma, (500,500))[50:250]
plt.imshow(irma, cmap='gray')

# %%
def gera_txt(img_ascii, name):
  img_ascii = img_ascii.astype('U')
  img_ascii = ascii_img(img_ascii)

  with open(f"{name}.txt",'w',encoding = 'utf-8') as f:
    h, w = img_ascii.shape
    x = ""
    for j in range(0,h):
      for i in img_ascii[j][:]:
        x+= i
      f.write(f"{x}\n")
      x = ""

# %%
gera_txt(mae1, "mae1")
gera_txt(mae2, "mae2")
gera_txt(irma, "irma")

# %%
chloe = cv2.imread("/content/drive/MyDrive/HistogramasPDI/imagens/chloe.png", cv2.IMREAD_GRAYSCALE)

# %%
chloe = cv2.GaussianBlur(chloe,(5,5),0)
chloe = cv2.Laplacian(chloe, 2)
chloe = cv2.resize(chloe, (400,150))
plt.imshow(chloe, cmap='gray')

# %%
gera_txt(chloe, "chloe")

# %%
#anthonyjake.jpg
gatos = cv2.imread("/content/drive/MyDrive/HistogramasPDI/imagens/anthonyjake.jpg", cv2.IMREAD_GRAYSCALE)

# %%
#gatos = cv2.GaussianBlur(gatos,(3,3),0)

# %%
gatos = cv2.GaussianBlur(gatos,(15,15),0)

# %%
gatos = cv2.Laplacian(gatos, 2)

# %%
gatos = cv2.resize(gatos, (900,600))

# %%
plt.imshow(gatos, cmap='gray')

# %%
gera_txt(gatos, "gatos")
